# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maceio
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | stanley
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | kourou
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | iringa
# Processing Record 9 of Set 1 | polyarnyy
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | opuwo
# Processing Record 12 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 13 of Set 1 | st. john's
# Processing Record 14 of Set 1 | sitka
# Processing Record 15 of Set 1 | kandahar
# Processing Record 16 of Set 1 | kyzyl-burun
# City not found. Skipping...
# Processing Record 17 of Set 1 | alofi
# Processing Record 18 of Set 1 | lima
# Processing Record 19 of Set 1 | abu ghurayb
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | olyokminsk
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | tabas
# Processing Record 24 of Set 1 | porto novo
# Processing Record 25 of Set 1 | qaqortoq
# Processing Record 26 of Set 1 | san antonio de pale
# Processing Record 27 of Set 1 | ancud
# Processing Record 28 of Set 1 | mendi
# Processing Record 29 of Set 1 | umm kaddadah
# Processing Record 30 of Set 1 | enewetak
# Processing Record 31 of Set 1 | puerto natales
# Processing Record 32 of Set 1 | olonkinbyen
# Processing Record 33 of Set 1 | afaahiti
# Processing Record 34 of Set 1 | tabou
# Processing Record 35 of Set 1 | rio grande
# Processing Record 36 of Set 1 | nyurba
# Processing Record 37 of Set 1 | port-aux-francais
# Processing Record 38 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 39 of Set 1 | papatowai
# Processing Record 40 of Set 1 | uturoa
# Processing Record 41 of Set 1 | bliss corner
# Processing Record 42 of Set 1 | invercargill
# Processing Record 43 of Set 1 | adamstown
# Processing Record 44 of Set 1 | ambon
# Processing Record 45 of Set 1 | madinat ash shamal
# Processing Record 46 of Set 1 | ta`u
# Processing Record 47 of Set 1 | two rivers
# Processing Record 48 of Set 1 | birao
# Processing Record 49 of Set 1 | bonthe
# Processing Record 50 of Set 1 | badger
# Processing Record 0 of Set 2 | waitangi
# Processing Record 1 of Set 2 | blackmans bay
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | fort bragg
# Processing Record 4 of Set 2 | rawson
# Processing Record 5 of Set 2 | lerwick
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | ulladulla
# Processing Record 8 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | clarksdale
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | chakia
# Processing Record 13 of Set 2 | princeville
# Processing Record 14 of Set 2 | lihue
# Processing Record 15 of Set 2 | riyadh
# Processing Record 16 of Set 2 | saynshand
# Processing Record 17 of Set 2 | grytviken
# Processing Record 18 of Set 2 | casa santa
# City not found. Skipping...
# Processing Record 19 of Set 2 | porto murtinho
# Processing Record 20 of Set 2 | sergeyevka
# Processing Record 21 of Set 2 | hawaiian paradise park
# Processing Record 22 of Set 2 | selfoss
# Processing Record 23 of Set 2 | eenhana
# Processing Record 24 of Set 2 | vernon
# Processing Record 25 of Set 2 | nema
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | hadibu
# Processing Record 28 of Set 2 | hrazdan
# Processing Record 29 of Set 2 | machico
# Processing Record 30 of Set 2 | leua
# Processing Record 31 of Set 2 | kingston
# Processing Record 32 of Set 2 | aitape
# Processing Record 33 of Set 2 | isafjordur
# Processing Record 34 of Set 2 | west island
# Processing Record 35 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 36 of Set 2 | faridkot
# Processing Record 37 of Set 2 | yabelo
# Processing Record 38 of Set 2 | bata
# Processing Record 39 of Set 2 | margaret river
# Processing Record 40 of Set 2 | puri
# Processing Record 41 of Set 2 | greymouth
# Processing Record 42 of Set 2 | chingirlau
# Processing Record 43 of Set 2 | kuqa
# Processing Record 44 of Set 2 | atafu village
# Processing Record 45 of Set 2 | yagry
# City not found. Skipping...
# Processing Record 46 of Set 2 | sishilichengzi
# City not found. Skipping...
# Processing Record 47 of Set 2 | celestun
# Processing Record 48 of Set 2 | la passe
# Processing Record 49 of Set 2 | berezovyy
# Processing Record 0 of Set 3 | fale old settlement
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | ciudad melchor muzquiz
# Processing Record 3 of Set 3 | dazhou
# Processing Record 4 of Set 3 | tolanaro
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 3 | muisne
# Processing Record 8 of Set 3 | ushuaia
# Processing Record 9 of Set 3 | el granada
# Processing Record 10 of Set 3 | sola
# Processing Record 11 of Set 3 | bilibino
# Processing Record 12 of Set 3 | kerikeri
# Processing Record 13 of Set 3 | colonia
# Processing Record 14 of Set 3 | gadzhiyevo
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | port mathurin
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | nogliki
# Processing Record 19 of Set 3 | colares
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | tebingtinggi
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | sao felix do xingu
# Processing Record 24 of Set 3 | pulandian
# Processing Record 25 of Set 3 | salinopolis
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | cestos city
# Processing Record 28 of Set 3 | tazovsky
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | tapes
# Processing Record 31 of Set 3 | bulata
# Processing Record 32 of Set 3 | krasnyy kut
# Processing Record 33 of Set 3 | esikhaleni
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | ormara
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | whitehorse
# Processing Record 38 of Set 3 | vila velha
# Processing Record 39 of Set 3 | daru
# Processing Record 40 of Set 3 | san julian
# Processing Record 41 of Set 3 | dudinka
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | pisco
# Processing Record 44 of Set 3 | haiku-pauwela
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | north bend
# Processing Record 48 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 49 of Set 3 | shahkot
# Processing Record 0 of Set 4 | jamestown
# Processing Record 1 of Set 4 | nar'yan-mar
# Processing Record 2 of Set 4 | tawau
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | keflavik
# Processing Record 5 of Set 4 | ouarzazat
# Processing Record 6 of Set 4 | vega de alatorre
# Processing Record 7 of Set 4 | palmer
# Processing Record 8 of Set 4 | hobyo
# Processing Record 9 of Set 4 | rikaze
# Processing Record 10 of Set 4 | udachny
# Processing Record 11 of Set 4 | wladyslawowo
# Processing Record 12 of Set 4 | wajir
# Processing Record 13 of Set 4 | wynyard
# Processing Record 14 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 15 of Set 4 | albany
# Processing Record 16 of Set 4 | nadym
# Processing Record 17 of Set 4 | kamiiso
# Processing Record 18 of Set 4 | fort mcmurray
# Processing Record 19 of Set 4 | aasiaat
# Processing Record 20 of Set 4 | wailua homesteads
# Processing Record 21 of Set 4 | kapa'a
# Processing Record 22 of Set 4 | bathsheba
# Processing Record 23 of Set 4 | fonadhoo
# City not found. Skipping...
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | kushiro
# Processing Record 26 of Set 4 | bambanglipuro
# Processing Record 27 of Set 4 | nikolayevsk-on-amure
# Processing Record 28 of Set 4 | corn island
# Processing Record 29 of Set 4 | faya-largeau
# Processing Record 30 of Set 4 | vorgashor
# Processing Record 31 of Set 4 | copala
# Processing Record 32 of Set 4 | prabumulih
# Processing Record 33 of Set 4 | altinekin
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 4 | roma
# Processing Record 37 of Set 4 | santa cruz
# Processing Record 38 of Set 4 | rudnichnyy
# Processing Record 39 of Set 4 | kayangel
# Processing Record 40 of Set 4 | koulikoro
# Processing Record 41 of Set 4 | arno
# Processing Record 42 of Set 4 | la foa
# Processing Record 43 of Set 4 | mirnyy
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | waynesboro
# Processing Record 46 of Set 4 | chonchi
# Processing Record 47 of Set 4 | leava
# Processing Record 48 of Set 4 | pangody
# Processing Record 49 of Set 4 | crane
# Processing Record 0 of Set 5 | sao joao da barra
# Processing Record 1 of Set 5 | hammerfest
# Processing Record 2 of Set 5 | hermanus
# Processing Record 3 of Set 5 | khandyga
# Processing Record 4 of Set 5 | port saint john's
# Processing Record 5 of Set 5 | rangkasbitung
# Processing Record 6 of Set 5 | cartagena
# Processing Record 7 of Set 5 | usogorsk
# Processing Record 8 of Set 5 | centar zupa
# Processing Record 9 of Set 5 | kruisfontein
# Processing Record 10 of Set 5 | aykhal
# Processing Record 11 of Set 5 | constantia
# Processing Record 12 of Set 5 | qamdo
# Processing Record 13 of Set 5 | dalandzadgad
# Processing Record 14 of Set 5 | la paz
# Processing Record 15 of Set 5 | brisas de zicatela
# Processing Record 16 of Set 5 | lagos
# Processing Record 17 of Set 5 | grantsville
# Processing Record 18 of Set 5 | muscat
# Processing Record 19 of Set 5 | mineiros
# Processing Record 20 of Set 5 | caleta de carquin
# Processing Record 21 of Set 5 | champerico
# Processing Record 22 of Set 5 | kulhudhuffushi
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 25 of Set 5 | holualoa
# Processing Record 26 of Set 5 | vilyuchinsk
# Processing Record 27 of Set 5 | whangarei
# Processing Record 28 of Set 5 | beneditinos
# Processing Record 29 of Set 5 | tateyama
# Processing Record 30 of Set 5 | bac lieu
# Processing Record 31 of Set 5 | meiningen
# Processing Record 32 of Set 5 | maxixe
# Processing Record 33 of Set 5 | ribeira grande
# Processing Record 34 of Set 5 | kyzyl-suu
# Processing Record 35 of Set 5 | tarauaca
# Processing Record 36 of Set 5 | nagqu
# Processing Record 37 of Set 5 | nemuro
# Processing Record 38 of Set 5 | neryungri
# Processing Record 39 of Set 5 | yinchuan
# Processing Record 40 of Set 5 | laminusa
# Processing Record 41 of Set 5 | bambang
# Processing Record 42 of Set 5 | huarmey
# Processing Record 43 of Set 5 | utrik
# Processing Record 44 of Set 5 | pechora
# Processing Record 45 of Set 5 | dubbo
# Processing Record 46 of Set 5 | le port
# Processing Record 47 of Set 5 | galesong
# Processing Record 48 of Set 5 | arbroath
# Processing Record 49 of Set 5 | santa ana
# Processing Record 0 of Set 6 | midvagur
# Processing Record 1 of Set 6 | hargeysa
# Processing Record 2 of Set 6 | kuusamo
# Processing Record 3 of Set 6 | laguna
# Processing Record 4 of Set 6 | cururupu
# Processing Record 5 of Set 6 | ouadda
# Processing Record 6 of Set 6 | queenstown
# Processing Record 7 of Set 6 | minas de marcona
# Processing Record 8 of Set 6 | zelenoborskiy
# Processing Record 9 of Set 6 | bikenibeu village
# Processing Record 10 of Set 6 | kristiansund
# Processing Record 11 of Set 6 | tucuma
# Processing Record 12 of Set 6 | susuman
# Processing Record 13 of Set 6 | tralee
# Processing Record 14 of Set 6 | mitchell
# Processing Record 15 of Set 6 | armacao de buzios
# Processing Record 16 of Set 6 | grand-bourg
# Processing Record 17 of Set 6 | mahroni
# Processing Record 18 of Set 6 | agat village
# Processing Record 19 of Set 6 | horta
# Processing Record 20 of Set 6 | great bend
# Processing Record 21 of Set 6 | kalispell
# Processing Record 22 of Set 6 | deqen
# Processing Record 23 of Set 6 | penhalonga
# Processing Record 24 of Set 6 | hof
# Processing Record 25 of Set 6 | bridgewater
# Processing Record 26 of Set 6 | lautoka
# Processing Record 27 of Set 6 | sisimiut
# Processing Record 28 of Set 6 | oualidia
# City not found. Skipping...
# Processing Record 29 of Set 6 | kokologo
# Processing Record 30 of Set 6 | kattivakkam
# Processing Record 31 of Set 6 | los frentones
# Processing Record 32 of Set 6 | baruun-urt
# Processing Record 33 of Set 6 | brak
# Processing Record 34 of Set 6 | borogontsy
# Processing Record 35 of Set 6 | viedma
# Processing Record 36 of Set 6 | bowen
# Processing Record 37 of Set 6 | tuy hoa
# Processing Record 38 of Set 6 | abu qurqas
# Processing Record 39 of Set 6 | jan kempdorp
# Processing Record 40 of Set 6 | afif
# Processing Record 41 of Set 6 | kamianske
# Processing Record 42 of Set 6 | nuuk
# Processing Record 43 of Set 6 | yaritagua
# Processing Record 44 of Set 6 | humaita
# Processing Record 45 of Set 6 | galliano
# Processing Record 46 of Set 6 | necochea
# Processing Record 47 of Set 6 | micheweni
# Processing Record 48 of Set 6 | ust-nera
# Processing Record 49 of Set 6 | tual
# Processing Record 0 of Set 7 | mangrol
# Processing Record 1 of Set 7 | loiza
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | sinabang
# Processing Record 4 of Set 7 | nakano
# Processing Record 5 of Set 7 | el sauzal de rodriguez
# Processing Record 6 of Set 7 | aswan
# Processing Record 7 of Set 7 | tambopata
# Processing Record 8 of Set 7 | lubang
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | kidal
# Processing Record 11 of Set 7 | franceville
# Processing Record 12 of Set 7 | mongo
# Processing Record 13 of Set 7 | sao vicente
# Processing Record 14 of Set 7 | tocopilla
# Processing Record 15 of Set 7 | baotou
# Processing Record 16 of Set 7 | slutsk
# Processing Record 17 of Set 7 | moramanga
# Processing Record 18 of Set 7 | tyukhtet
# Processing Record 19 of Set 7 | sangueya
# Processing Record 20 of Set 7 | farasan
# Processing Record 21 of Set 7 | baidoa
# Processing Record 22 of Set 7 | tobelo
# Processing Record 23 of Set 7 | anadyr
# Processing Record 24 of Set 7 | kalaleh
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | nova sintra
# Processing Record 27 of Set 7 | egilsstadir
# Processing Record 28 of Set 7 | morehead city
# Processing Record 29 of Set 7 | ankang
# Processing Record 30 of Set 7 | kuala kangsar
# Processing Record 31 of Set 7 | portrush
# Processing Record 32 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 33 of Set 7 | peniche
# Processing Record 34 of Set 7 | sydney
# Processing Record 35 of Set 7 | toulepleu guere
# Processing Record 36 of Set 7 | labytnangi
# Processing Record 37 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 38 of Set 7 | portland
# Processing Record 39 of Set 7 | hoxtolgay
# City not found. Skipping...
# Processing Record 40 of Set 7 | trinity beach
# Processing Record 41 of Set 7 | klyuchi
# Processing Record 42 of Set 7 | luanco
# Processing Record 43 of Set 7 | oum hadjer
# Processing Record 44 of Set 7 | remire-montjoly
# Processing Record 45 of Set 7 | belmonte
# Processing Record 46 of Set 7 | gargalianoi
# Processing Record 47 of Set 7 | ghat
# Processing Record 48 of Set 7 | villa canas
# Processing Record 49 of Set 7 | iguape
# Processing Record 0 of Set 8 | kone
# Processing Record 1 of Set 8 | dadukou
# Processing Record 2 of Set 8 | fuzesabony
# Processing Record 3 of Set 8 | batticaloa
# Processing Record 4 of Set 8 | zmeinogorsk
# Processing Record 5 of Set 8 | mount pearl
# Processing Record 6 of Set 8 | ketchikan
# Processing Record 7 of Set 8 | solnechnyy
# Processing Record 8 of Set 8 | yuzhno-kurilsk
# Processing Record 9 of Set 8 | kodinsk
# Processing Record 10 of Set 8 | kununurra
# Processing Record 11 of Set 8 | hazorasp
# Processing Record 12 of Set 8 | palikir - national government center
# Processing Record 13 of Set 8 | karachi
# Processing Record 14 of Set 8 | la tuque
# Processing Record 15 of Set 8 | kanel
# Processing Record 16 of Set 8 | fisterra
# Processing Record 17 of Set 8 | tera
# Processing Record 18 of Set 8 | dogubayazit
# Processing Record 19 of Set 8 | verkhnevilyuysk
# Processing Record 20 of Set 8 | maintirano
# Processing Record 21 of Set 8 | west end
# Processing Record 22 of Set 8 | kiruna
# Processing Record 23 of Set 8 | troitsk
# Processing Record 24 of Set 8 | boysun
# Processing Record 25 of Set 8 | renk
# City not found. Skipping...
# Processing Record 26 of Set 8 | namibe
# Processing Record 27 of Set 8 | banda aceh
# Processing Record 28 of Set 8 | tevragh zeina
# City not found. Skipping...
# Processing Record 29 of Set 8 | kikwit
# Processing Record 30 of Set 8 | sen monorom
# Processing Record 31 of Set 8 | nouadhibou
# Processing Record 32 of Set 8 | tshabong
# Processing Record 33 of Set 8 | puerto baquerizo moreno
# Processing Record 34 of Set 8 | hasaki
# Processing Record 35 of Set 8 | wewak
# Processing Record 36 of Set 8 | mahina
# Processing Record 37 of Set 8 | mitsamiouli
# Processing Record 38 of Set 8 | severo-yeniseyskiy
# Processing Record 39 of Set 8 | paka
# Processing Record 40 of Set 8 | kokstad
# Processing Record 41 of Set 8 | nereta
# City not found. Skipping...
# Processing Record 42 of Set 8 | fish town
# Processing Record 43 of Set 8 | puerto deseado
# Processing Record 44 of Set 8 | plouzane
# Processing Record 45 of Set 8 | santana
# Processing Record 46 of Set 8 | saint-philippe
# Processing Record 47 of Set 8 | rajin
# Processing Record 48 of Set 8 | lubny
# Processing Record 49 of Set 8 | zhangye
# Processing Record 0 of Set 9 | antonio enes
# Processing Record 1 of Set 9 | amos
# Processing Record 2 of Set 9 | la'ie
# Processing Record 3 of Set 9 | balnearia
# Processing Record 4 of Set 9 | hanceville
# Processing Record 5 of Set 9 | akobo
# Processing Record 6 of Set 9 | bati
# Processing Record 7 of Set 9 | gorontalo
# Processing Record 8 of Set 9 | ebon
# Processing Record 9 of Set 9 | i-n-salah
# Processing Record 10 of Set 9 | lodja
# Processing Record 11 of Set 9 | moyale
# Processing Record 12 of Set 9 | newman
# Processing Record 13 of Set 9 | freetown
# Processing Record 14 of Set 9 | saint-pierre
# Processing Record 15 of Set 9 | palu
# Processing Record 16 of Set 9 | ulanhot
# Processing Record 17 of Set 9 | fomboni
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | ocean shores
# Processing Record 20 of Set 9 | yarmouth
# Processing Record 21 of Set 9 | anchorage
# Processing Record 22 of Set 9 | dainville
# Processing Record 23 of Set 9 | sofifi
# City not found. Skipping...
# Processing Record 24 of Set 9 | motueka
# Processing Record 25 of Set 9 | dekina
# Processing Record 26 of Set 9 | taos
# Processing Record 27 of Set 9 | tromso
# Processing Record 28 of Set 9 | the dalles
# Processing Record 29 of Set 9 | ola
# Processing Record 30 of Set 9 | elmendorf air force base
# City not found. Skipping...
# Processing Record 31 of Set 9 | sirte
# Processing Record 32 of Set 9 | ploneour-lanvern
# Processing Record 33 of Set 9 | saipan
# Processing Record 34 of Set 9 | ailuk
# Processing Record 35 of Set 9 | angaur state
# Processing Record 36 of Set 9 | merta
# Processing Record 37 of Set 9 | khambhaliya
# Processing Record 38 of Set 9 | tambacounda
# Processing Record 39 of Set 9 | waiuku
# Processing Record 40 of Set 9 | tommot
# Processing Record 41 of Set 9 | umba
# Processing Record 42 of Set 9 | coahuayana de hidalgo
# Processing Record 43 of Set 9 | iskateley
# Processing Record 44 of Set 9 | sakchu-up
# Processing Record 45 of Set 9 | jose de freitas
# Processing Record 46 of Set 9 | aketi
# Processing Record 47 of Set 9 | sapucaia
# Processing Record 48 of Set 9 | pacific grove
# Processing Record 49 of Set 9 | luganville
# Processing Record 0 of Set 10 | saint-francois
# Processing Record 1 of Set 10 | berdigestyakh
# Processing Record 2 of Set 10 | cabedelo
# Processing Record 3 of Set 10 | rock springs
# Processing Record 4 of Set 10 | margate
# Processing Record 5 of Set 10 | namtsy
# Processing Record 6 of Set 10 | thisted
# Processing Record 7 of Set 10 | aguadas
# Processing Record 8 of Set 10 | porbandar
# Processing Record 9 of Set 10 | missoula
# Processing Record 10 of Set 10 | broken hill
# Processing Record 11 of Set 10 | saskatoon
# Processing Record 12 of Set 10 | magadan
# Processing Record 13 of Set 10 | buala
# Processing Record 14 of Set 10 | pangkalanbuun
# Processing Record 15 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 10 | cole harbour
# Processing Record 17 of Set 10 | adrar
# Processing Record 18 of Set 10 | colle di val d'elsa
# Processing Record 19 of Set 10 | tughyl
# Processing Record 20 of Set 10 | nizhnevartovsk
# Processing Record 21 of Set 10 | island harbour
# Processing Record 22 of Set 10 | lucapa
# Processing Record 23 of Set 10 | kertih
# Processing Record 24 of Set 10 | neftcala
# Processing Record 25 of Set 10 | kudahuvadhoo
# Processing Record 26 of Set 10 | balsas
# Processing Record 27 of Set 10 | port hedland
# Processing Record 28 of Set 10 | revda
# Processing Record 29 of Set 10 | ciudad sabinas hidalgo
# Processing Record 30 of Set 10 | zlocieniec
# Processing Record 31 of Set 10 | mahibadhoo
# Processing Record 32 of Set 10 | takoradi
# Processing Record 33 of Set 10 | tura
# Processing Record 34 of Set 10 | tafalla
# Processing Record 35 of Set 10 | chu
# Processing Record 36 of Set 10 | kutum
# Processing Record 37 of Set 10 | smolyaninovo
# Processing Record 38 of Set 10 | areia branca
# Processing Record 39 of Set 10 | qarazhal
# Processing Record 40 of Set 10 | manokwari
# Processing Record 41 of Set 10 | settat
# Processing Record 42 of Set 10 | cheremushki
# Processing Record 43 of Set 10 | tonghae
# Processing Record 44 of Set 10 | vadso
# Processing Record 45 of Set 10 | cooper's town
# Processing Record 46 of Set 10 | sonoita
# Processing Record 47 of Set 10 | pul-e khumri
# Processing Record 48 of Set 10 | kiknur
# Processing Record 49 of Set 10 | maitum
# Processing Record 0 of Set 11 | labuan
# Processing Record 1 of Set 11 | colac
# Processing Record 2 of Set 11 | murray bridge
# Processing Record 3 of Set 11 | pingdingshan
# Processing Record 4 of Set 11 | muana
# Processing Record 5 of Set 11 | kokpekty
# Processing Record 6 of Set 11 | chenzhou
# Processing Record 7 of Set 11 | vohimanitra
# City not found. Skipping...
# Processing Record 8 of Set 11 | salym
# Processing Record 9 of Set 11 | aligudarz
# Processing Record 10 of Set 11 | katsuren-haebaru
# Processing Record 11 of Set 11 | scottburgh
# Processing Record 12 of Set 11 | waitara
# Processing Record 13 of Set 11 | guerrero negro
# Processing Record 14 of Set 11 | galle
# Processing Record 15 of Set 11 | dunedin
# Processing Record 16 of Set 11 | kuta
# Processing Record 17 of Set 11 | kailua-kona
# Processing Record 18 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 19 of Set 11 | barcelos
# Processing Record 20 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 11 | rodez
# Processing Record 22 of Set 11 | yamada
# Processing Record 23 of Set 11 | carlsbad
# Processing Record 24 of Set 11 | emerald
# Processing Record 25 of Set 11 | malango
# Processing Record 26 of Set 11 | oruro
# Processing Record 27 of Set 11 | tsiombe
# Processing Record 28 of Set 11 | kerema
# Processing Record 29 of Set 11 | labrador city
# Processing Record 30 of Set 11 | musan-up
# Processing Record 31 of Set 11 | kirakira
# Processing Record 32 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 33 of Set 11 | ijuw
# City not found. Skipping...
# Processing Record 34 of Set 11 | summerside
# Processing Record 35 of Set 11 | ixtapa
# Processing Record 36 of Set 11 | dawukou
# Processing Record 37 of Set 11 | la almunia de dona godina
# Processing Record 38 of Set 11 | ankazoabo
# Processing Record 39 of Set 11 | guilin
# Processing Record 40 of Set 11 | silver city
# Processing Record 41 of Set 11 | axim
# Processing Record 42 of Set 11 | papao
# Processing Record 43 of Set 11 | moyynkum
# Processing Record 44 of Set 11 | asaita
# Processing Record 45 of Set 11 | dobrush
# Processing Record 46 of Set 11 | port alfred
# Processing Record 47 of Set 11 | palencia
# Processing Record 48 of Set 11 | la ronge
# Processing Record 49 of Set 11 | nkurenkuru
# City not found. Skipping...
# Processing Record 0 of Set 12 | soldato-aleksandrovskoye
# Processing Record 1 of Set 12 | coxim
# Processing Record 2 of Set 12 | rongelap
# Processing Record 3 of Set 12 | korneuburg
# Processing Record 4 of Set 12 | khamis mushait
# Processing Record 5 of Set 12 | kolonia
# Processing Record 6 of Set 12 | essaouira
# Processing Record 7 of Set 12 | muang phon-hong
# Processing Record 8 of Set 12 | togur
# Processing Record 9 of Set 12 | forster
# Processing Record 10 of Set 12 | akureyri
# Processing Record 11 of Set 12 | sihanoukville
# Processing Record 12 of Set 12 | soria
# Processing Record 13 of Set 12 | yamoussoukro
# Processing Record 14 of Set 12 | sambava
# Processing Record 15 of Set 12 | volchikha
# Processing Record 16 of Set 12 | katabu
# Processing Record 17 of Set 12 | patterson
# Processing Record 18 of Set 12 | weno
# Processing Record 19 of Set 12 | talara
# Processing Record 20 of Set 12 | flying fish cove
# Processing Record 21 of Set 12 | evanston
# Processing Record 22 of Set 12 | xacmaz
# Processing Record 23 of Set 12 | tamalous
# Processing Record 24 of Set 12 | summerville
# Processing Record 25 of Set 12 | as sulayyil
# Processing Record 26 of Set 12 | toliara
# Processing Record 27 of Set 12 | menongue
# Processing Record 28 of Set 12 | cabo san lucas
# Processing Record 29 of Set 12 | aral
# Processing Record 30 of Set 12 | plastun
# Processing Record 31 of Set 12 | bulgan
# Processing Record 32 of Set 12 | bodenwerder
# Processing Record 33 of Set 12 | turpan
# Processing Record 34 of Set 12 | massawa
# Processing Record 35 of Set 12 | sullivan
# Processing Record 36 of Set 12 | shingu
# Processing Record 37 of Set 12 | akjoujt
# Processing Record 38 of Set 12 | port isabel
# Processing Record 39 of Set 12 | mil'kovo
# Processing Record 40 of Set 12 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 12 | nsanje
# Processing Record 15 of Set 12 | xuchang
# Processing Record 16 of Set 12 | todos santos
# Processing Record 17 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 12 | bataipora
# Processing Record 19 of Set 12 | tateyama
# Processing Record 20 of Set 12 | wajima
# Processing Record 21 of Set 12 | pokosnoye
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | yaring
# Processing Record 24 of Set 12 | isiro
# Processing Record 25 of Set 12 | chivilcoy
# Processing Record 26 of Set 12 | mandalgovi
# Processing Record 27 of Set 12 | nicoya
# Processing Record 28 of Set 12 | novocheremshansk
# Processing Record 29 of Set 12 | emirdag
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | tongliao
# Processing Record 32 of Set 12 | ryomgard
# Processing Record 33 of Set 12 | khudumelapye
# Processing Record 34 of Set 12 | talcahuano
# Processing Record 35 of Set 12 | gifhorn
# Processing Record 36 of Set 12 | bilma
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | kalabo
# Processing Record 40 of Set 12 | arcata
# Processing Record 41 of Set 12 | lemoore
# Processing Record 42 of Set 12 | norfolk
# Processing Record 43 of Set 12 | juba
# Processing Record 44 of Set 12 | pali
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | bambanglipuro
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | bulgan
# Processing Record 0 of Set 13 | sorland
# Processing Record 1 of Set 13 | saryg-sep
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | changli
# Processing Record 7 of Set 13 | choma
# Processing Record 8 of Set 13 | tena
# Processing Record 9 of Set 13 | ilhabela
# Processing Record 10 of Set 13 | redmond
# Processing Record 11 of Set 13 | wyndham
# Processing Record 12 of Set 13 | nhulunbuy
# Processing Record 13 of Set 13 | sangamner
# Processing Record 14 of Set 13 | road town
# Processing Record 15 of Set 13 | ranong
# Processing Record 16 of Set 13 | staryy nadym
# Processing Record 17 of Set 13 | dargaville
# Processing Record 18 of Set 13 | sovetskiy
# Processing Record 19 of Set 13 | tatarsk
# Processing Record 20 of Set 13 | canchungo
# Processing Record 21 of Set 13 | iquique
# Processing Record 22 of Set 13 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                       maceio  -9.6658  -35.7353     25.69        88
# 1  edinburgh of the seven seas -37.0676  -12.3116     18.82        93
# 2                       lompoc  34.6391 -120.4579     10.33        80
# 3                      stanley  54.8680   -1.6985     10.95        94
# 4                   bredasdorp -34.5322   20.0403     14.97        79
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        2.06      BR  1712371283
# 1          87       11.38      SH  1712371346
# 2           0        5.14      US  1712371346
# 3          75        4.63      GB  1712371328
# 4         100        7.58      ZA  1712371347

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                             maceio  -9.6658  -35.7353     25.69        88
# 1        edinburgh of the seven seas -37.0676  -12.3116     18.82        93
# 2                             lompoc  34.6391 -120.4579     10.33        80
# 3                            stanley  54.8680   -1.6985     10.95        94
# 4                         bredasdorp -34.5322   20.0403     14.97        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        2.06      BR  1712371283
# 1                87       11.38      SH  1712371346
# 2                 0        5.14      US  1712371346
# 3                75        4.63      GB  1712371328
# 4               100        7.58      ZA  1712371347

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lat_temp = city_data_df[["Lat", "Max Temp"]]
lat_temp.plot(kind='scatter', x='Lat', y='Max Temp', facecolors='darkblue', alpha=.8, edgecolor='black', s=40)

# Incorporate the other graph properties
date = pd.to_datetime(city_data_df['Date'][0], dayfirst=True).strftime('%Y-%m-%d')
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Max Latitude vs. Temperature ({date})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat_humid = city_data_df[["Lat", "Humidity"]]
lat_humid.plot(kind='scatter', x='Lat', y='Humidity', facecolors='darkblue', alpha=.8, edgecolor='black', s=40)

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({date})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lat_cloudy = city_data_df[["Lat", "Cloudiness"]]
lat_cloudy.plot(kind='scatter', x='Lat', y='Cloudiness', facecolors='darkblue', alpha=.8, edgecolor='black', s=40)

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({date})")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lat_wind = city_data_df[["Lat", "Wind Speed"]]
lat_wind.plot(kind='scatter', x='Lat', y='Wind Speed', facecolors='darkblue', alpha=.8, edgecolor='black', s=40)

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
